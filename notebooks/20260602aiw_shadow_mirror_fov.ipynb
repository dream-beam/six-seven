# %% [markdown]
# # Studying field effects on a ellipsoidal mirror
# awojdyla@lbl.gov, June 2026
#
# We are studying the effect of the field of view on the beam size in the case of synchrotron optical
#
# For the simulation, we consider a typical situation with an ellipsoidal mirror with an object distance p=15m and and an image distance q=5m, for a 2 deg grazing angle.
#
# The beam size is chosen to be 20 um-rms with a divergence of 50urad-rms, also quite typical.
#
# Note that this code may be hard to run in VSCode (you need an old version of Shadow and intel libs) but can easily be run in Oasys 1.x python widget

# %% [markdown]
# ## Sample code directly fromn Shadow
# do not use directly, this is just for reference

# %%
#
# Python script to run shadow3. Created automatically with ShadowTools.make_python_script_from_list().
#
import Shadow
import numpy

# write (1) or not (0) SHADOW files start.xx end.xx star.xx
iwrite = 0

#
# initialize shadow3 source (oe0) and beam
#
beam = Shadow.Beam()
oe0 = Shadow.Source()
oe1 = Shadow.OE()
oe2 = Shadow.OE()
oe3 = Shadow.OE()

#
# Define variables. See meaning of variables in: 
#  https://raw.githubusercontent.com/srio/shadow3/master/docs/source.nml 
#  https://raw.githubusercontent.com/srio/shadow3/master/docs/oe.nml
#

oe0.FDISTR = 3
oe0.F_COLOR = 2
oe0.F_PHOT = 0
oe0.F_POLAR = 0
oe0.HDIV1 = 0.0
oe0.HDIV2 = 0.0
oe0.IDO_VX = 0
oe0.IDO_VZ = 0
oe0.IDO_X_S = 0
oe0.IDO_Y_S = 0
oe0.IDO_Z_S = 0
oe0.ISTAR1 = 0
oe0.NPOINT = 100000
oe0.N_COLOR = 3
oe0.PH1 = 799.9
oe0.PH2 = 800.0
oe0.PH3 = 800.1
oe0.SIGDIX = 5e-05
oe0.SIGDIZ = 0.0
oe0.SIGMAX = 2e-05
oe0.SIGMAZ = 0.0
oe0.VDIV1 = 0.0
oe0.VDIV2 = 0.0

oe1.DUMMY = 100.0
oe1.FSTAT = 1
oe1.F_REFRAC = 2
oe1.F_SCREEN = 1
oe1.N_SCREEN = 1
oe1.RDSOUR = 15.0
oe1.T_IMAGE = 0.0
oe1.T_INCIDENCE = 0.0
oe1.T_REFLECTION = 180.0
oe1.T_SOURCE = 0.0
oe1.X_SOUR = 0.005
oe1.Y_SOUR = 1e-09
oe1.Z_SOUR = 1e-09

oe2.ALPHA = 90.0
oe2.DUMMY = 100.0
oe2.FCYL = 1
oe2.FMIRR = 2
oe2.FWRITE = 1
oe2.F_DEFAULT = 0
oe2.SIMAG = 5.0
oe2.SSOUR = 15.0
oe2.THETA = 88.0
oe2.T_IMAGE = 0.0
oe2.T_SOURCE = 0.0

oe3.DUMMY = 100.0
oe3.F_REFRAC = 2
oe3.F_SCREEN = 1
oe3.N_SCREEN = 1
oe3.T_IMAGE = 0.0
oe3.T_INCIDENCE = 0.0
oe3.T_REFLECTION = 180.0
oe3.T_SOURCE = 5.0



#Run SHADOW to create the source

if iwrite:
    oe0.write("start.00")

beam.genSource(oe0)

if iwrite:
    oe0.write("end.00")
    beam.write("begin.dat")


#
#run optical element 1
#
print("    Running optical element: %d"%(1))
if iwrite:
    oe1.write("start.01")

beam.traceOE(oe1,1)

if iwrite:
    oe1.write("end.01")
    beam.write("star.01")


#
#run optical element 2
#
print("    Running optical element: %d"%(2))
if iwrite:
    oe2.write("start.02")

beam.traceOE(oe2,2)

if iwrite:
    oe2.write("end.02")
    beam.write("star.02")


#
#run optical element 3
#
print("    Running optical element: %d"%(3))
if iwrite:
    oe3.write("start.03")

beam.traceOE(oe3,3)

if iwrite:
    oe3.write("end.03")
    beam.write("star.03")


Shadow.ShadowTools.plotxy(beam,1,3,nbins=101,nolost=1,title="Real space")
# Shadow.ShadowTools.plotxy(beam,1,4,nbins=101,nolost=1,title="Phase space X")
# Shadow.ShadowTools.plotxy(beam,3,6,nbins=101,nolost=1,title="Phase space Z")
# Out:
#  INIT_RANDOM_SEED: random seed initialised using system clock
#     Running optical element: 1
#     Running optical element: 2
#     Running optical element: 3
#  INIT_RANDOM_SEED: random seed initialised using system clock
#  Generated         5000  rays out of       100000
#                   10000
#                   15000
#                   20000
#                   25000
#                   30000
#                   35000
#                   40000
#                   45000
#                   50000
#                   55000
#                   60000
#                   65000
#                   70000
#                   75000
#                   80000
#                   85000
#                   90000
#                   95000
#                  100000
#  Exit from SOURCE
#  Call to RESET
#  Exit from RESET
#  Call to SETSOUR
#  Exit from SETSOUR
#  Call to IMREF
#  Exit from IMREF
#  Call to OPTAXIS
#  Exit from OPTAXIS
#  Call to MSETUP
#  Exit from MSETUP
#  Call to RESTART
#  Exit from RESTART
#  Call to MIRROR
#  MIRROR1: Warning: Empty element (no mirr.xx file)
#  Call to SCREEN
#  Exit from SCREEN
#  Call to IMAGE
#  Exit from IMAGE
#  Call to DEALLOC
#  Exit from DEALLOC
#  Call to RESET
#  Exit from RESET
#  Call to SETSOUR
#  Exit from SETSOUR
#  Call to IMREF
#  Exit from IMREF
#  Call to OPTAXIS
#  Exit from OPTAXIS
#  Call to MSETUP
#  Exit from MSETUP
#  Call to RESTART
#  Exit from RESTART
#  Call to MIRROR
#  Exit from MIRROR
#  Call to IMAGE
#  Exit from IMAGE
#  Call to DEALLOC
#  Exit from DEALLOC
#  Call to RESET
#  Exit from RESET
#  Call to SETSOUR
#  Exit from SETSOUR
#  Call to IMREF
#  Exit from IMREF
#  Call to OPTAXIS
#  Exit from OPTAXIS
#  Call to MSETUP
#  Exit from MSETUP
#  Call to RESTART
#  Exit from RESTART
#  Call to MIRROR
#  MIRROR1: Warning: Empty element (no mirr.xx file)
#  Call to SCREEN
#  Exit from SCREEN
#  Call to IMAGE
#  Exit from IMAGE
#  Call to DEALLOC
#  Exit from DEALLOC
# {'error': 1,
#  'col_h': 1,
#  'col_v': 3,
#  'nolost': 1,
#  'nbins_h': 101,
#  'nbins_v': 101,
#  'ref': 23,
#  'xrange': [9.999993876816845e-10, 9.999993882782724e-10],
#  'yrange': [-0.0017902820560557924, -0.0016794694896903725],
#  'bin_h_edges': array([9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10]),
#  'bin_v_edges': array([-0.00179028, -0.00178918, -0.00178809, -0.00178699, -0.00178589,
#         -0.0017848 , -0.0017837 , -0.0017826 , -0.0017815 , -0.00178041,
#         -0.00177931, -0.00177821, -0.00177712, -0.00177602, -0.00177492,
#         -0.00177382, -0.00177273, -0.00177163, -0.00177053, -0.00176944,
#         -0.00176834, -0.00176724, -0.00176614, -0.00176505, -0.00176395,
#         -0.00176285, -0.00176176, -0.00176066, -0.00175956, -0.00175846,
#         -0.00175737, -0.00175627, -0.00175517, -0.00175408, -0.00175298,
#         -0.00175188, -0.00175078, -0.00174969, -0.00174859, -0.00174749,
#         -0.0017464 , -0.0017453 , -0.0017442 , -0.0017431 , -0.00174201,
#         -0.00174091, -0.00173981, -0.00173872, -0.00173762, -0.00173652,
#         -0.00173542, -0.00173433, -0.00173323, -0.00173213, -0.00173104,
#         -0.00172994, -0.00172884, -0.00172774, -0.00172665, -0.00172555,
#         -0.00172445, -0.00172336, -0.00172226, -0.00172116, -0.00172006,
#         -0.00171897, -0.00171787, -0.00171677, -0.00171568, -0.00171458,
#         -0.00171348, -0.00171238, -0.00171129, -0.00171019, -0.00170909,
#         -0.001708  , -0.0017069 , -0.0017058 , -0.0017047 , -0.00170361,
#         -0.00170251, -0.00170141, -0.00170032, -0.00169922, -0.00169812,
#         -0.00169702, -0.00169593, -0.00169483, -0.00169373, -0.00169264,
#         -0.00169154, -0.00169044, -0.00168934, -0.00168825, -0.00168715,
#         -0.00168605, -0.00168496, -0.00168386, -0.00168276, -0.00168166,
#         -0.00168057, -0.00167947]),
#  'bin_h_left': array([9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-10, 9.99999388e-10, 9.99999388e-10, 9.99999388e-10,
#         9.99999388e-
#         1.237e+03, 1.069e+03, 8.830e+02, 7.680e+02, 6.260e+02, 5.470e+02,
#         4.230e+02, 3.310e+02, 2.950e+02, 2.500e+02, 2.030e+02, 1.340e+02,
#         1.240e+02, 7.900e+01, 5.600e+01, 6.500e+01, 3.700e+01, 2.900e+01,
#         1.900e+01, 7.000e+00, 8.000e+00, 8.000e+00, 6.000e+00, 4.000e+00,
#         3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00]),
#  'histogram_v': array([0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 1.000e+00, 2.000e+00, 1.000e+00,
#         3.000e+00, 1.000e+01, 8.000e+00, 5.000e+00, 1.500e+01, 2.200e+01,
#         2.600e+01, 2.600e+01, 3.900e+01, 4.100e+01, 8.500e+01, 8.900e+01,
#         1.170e+02, 1.420e+02, 1.790e+02, 2.370e+02, 3.190e+02, 3.270e+02,
#         4.250e+02, 4.490e+02, 6.000e+02, 7.030e+02, 8.550e+02, 9.370e+02,
#         1.126e+03, 1.274e+03, 1.445e+03, 1.621e+03, 1.830e+03, 1.967e+03,
#         2.240e+03, 2.390e+03, 2.556e+03, 2.716e+03, 2.991e+03, 3.130e+03,
#         3.299e+03, 3.378e+03, 3.493e+03, 3.409e+03, 3.457e+03, 3.555e+03,
#         3.531e+03, 3.447e+03, 3.562e+03, 3.406e+03, 3.343e+03, 3.044e+03,
#         2.938e+03, 2.771e+03, 2.654e+03, 2.486e+03, 2.246e+03, 2.035e+03,
#         1.793e+03, 1.651e+03, 1.422e+03, 1.302e+03, 1.145e+03, 9.600e+02,
#         8.840e+02, 7.230e+02, 5.950e+02, 5.270e+02, 4.140e+02, 3.380e+02,
#         2.540e+02, 2.200e+02, 1.740e+02, 1.290e+02, 1.070e+02, 8.200e+01,
#         6.700e+01, 4.500e+01, 3.600e+01, 3.200e+01, 3.400e+01, 1.200e+01,
#         1.800e+01, 1.100e+01, 5.000e+00, 6.000e+00, 2.000e+00, 4.000e+00,
#         3.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00]),
#  'intensity': 100000.00000000001,
#  'nrays': 100000,
#  'good_rays': 100000,
#  'fwhm_h': 1.3585386905902474e-19,
#  'fwhm_coordinates_h': (9.999993879150034e-10, 9.999993880508602e-10),
#  'fwhm_v': 2.8526007183177736e-05,
#  'fwhm_coordinates_v': (-0.0017458473140973814, -0.001717321306914204)}

# %% [markdown]
# ## Stripped down code
# do not use directly, this is just for commenting and debugginh

# %%
import Shadow
import numpy

beam = Shadow.Beam()
oe0 = Shadow.Source()
oe1 = Shadow.OE()
oe2 = Shadow.OE()
oe3 = Shadow.OE()

# source
oe0.FDISTR = 3
oe0.F_COLOR = 2
oe0.F_PHOT = 0
oe0.F_POLAR = 0
oe0.HDIV1 = 0.0
oe0.HDIV2 = 0.0
oe0.IDO_VX = 0
oe0.IDO_VZ = 0
oe0.IDO_X_S = 0
oe0.IDO_Y_S = 0
oe0.IDO_Z_S = 0
oe0.ISTAR1 = 0
oe0.NPOINT = 100000
oe0.N_COLOR = 3
oe0.PH1 = 799.9
oe0.PH2 = 800.0
oe0.PH3 = 800.1
oe0.SIGDIX = 5e-05
oe0.SIGDIZ = 0.0
oe0.SIGMAX = 2e-05
oe0.SIGMAZ = 0.0
oe0.VDIV1 = 0.0
oe0.VDIV2 = 0.0

# dummy slits tro define source motion
oe1.DUMMY = 100.0
oe1.FSTAT = 1
oe1.F_REFRAC = 2
oe1.F_SCREEN = 1
oe1.N_SCREEN = 1
oe1.RDSOUR = 15.0
oe1.T_IMAGE = 0.0
oe1.T_INCIDENCE = 0.0
oe1.T_REFLECTION = 180.0
oe1.T_SOURCE = 0.0
# source motion is here
oe1.X_SOUR = 0.005
oe1.Y_SOUR = 1e-09
oe1.Z_SOUR = 1e-09

# ellipsoidal mirror, cojugate parameters with internally calculated parameters
oe2.ALPHA = 90.0
oe2.DUMMY = 100.0
oe2.FCYL = 1
oe2.FMIRR = 2
oe2.FWRITE = 1
oe2.F_DEFAULT = 0
#q
oe2.SIMAG = 5.0
#p
oe2.SSOUR = 15.0
# grazing angle
oe2.THETA = 88.0
oe2.T_IMAGE = 0.0
oe2.T_SOURCE = 0.0

oe3.DUMMY = 100.0
oe3.F_REFRAC = 2
oe3.F_SCREEN = 1
oe3.N_SCREEN = 1
oe3.T_IMAGE = 0.0
oe3.T_INCIDENCE = 0.0
oe3.T_REFLECTION = 180.0
oe3.T_SOURCE = 5.0


beam.genSource(oe0)
beam.traceOE(oe1,1)
beam.traceOE(oe2,2)
beam.traceOE(oe3,3)

x = beam.getshcol(1)
y = beam.getshcol(3)

#x_size_rms_m = numpy.std(x)

#beam size
y_size_rms_m = numpy.std(y)

#Shadow.ShadowTools.plotxy(beam,1,3,nbins=101,nolost=1,title="Real space")
# Shadow.ShadowTools.plotxy(beam,1,4,nbins=101,nolost=1,title="Phase space X")
# Shadow.ShadowTools.plotxy(beam,3,6,nbins=101,nolost=1,title="Phase space Z")
# Out:
#  INIT_RANDOM_SEED: random seed initialised using system clock
#  Generated         5000  rays out of       100000
#                   10000
#                   15000
#                   20000
#                   25000
#                   30000
#                   35000
#                   40000
#                   45000
#                   50000
#                   55000
#                   60000
#                   65000
#                   70000
#                   75000
#                   80000
#                   85000
#                   90000
#                   95000
#                  100000
#  Exit from SOURCE
#  Call to RESET
#  Exit from RESET
#  Call to SETSOUR
#  Exit from SETSOUR
#  Call to IMREF
#  Exit from IMREF
#  Call to OPTAXIS
#  Exit from OPTAXIS
#  Call to MSETUP
#  Exit from MSETUP
#  Call to RESTART
#  Exit from RESTART
#  Call to MIRROR
#  MIRROR1: Warning: Empty element (no mirr.xx file)
#  Call to SCREEN
#  Exit from SCREEN
#  Call to IMAGE
#  Exit from IMAGE
#  Call to DEALLOC
#  Exit from DEALLOC
#  Call to RESET
#  Exit from RESET
#  Call to SETSOUR
#  Exit from SETSOUR
#  Call to IMREF
#  Exit from IMREF
#  Call to OPTAXIS
#  Exit from OPTAXIS
#  Call to MSETUP
#  Exit from MSETUP
#  Call to RESTART
#  Exit from RESTART
#  Call to MIRROR
#  Exit from MIRROR
#  Call to IMAGE
#  Exit from IMAGE
#  Call to DEALLOC
#  Exit from DEALLOC
#  Call to RESET
#  Exit from RESET
#  Call to SETSOUR
#  Exit from SETSOUR
#  Call to IMREF
#  Exit from IMREF
#  Call to OPTAXIS
#  Exit from OPTAXIS
#  Call to MSETUP
#  Exit from MSETUP
#  Call to RESTART
#  Exit from RESTART
#  Call to MIRROR
#  MIRROR1: Warning: Empty element (no mirr.xx file)
#  Call to SCREEN
#  Exit from SCREEN
#  Call to IMAGE
#  Exit from IMAGE
#  Call to DEALLOC
#  Exit from DEALLOC

# %% [markdown]
# ## function linking beam size to field of view
# beam size = F(relaive source position)

# %%
def shadow_field_size(y_pos_m):

    beam = Shadow.Beam()
    oe0 = Shadow.Source()
    oe1 = Shadow.OE()
    oe2 = Shadow.OE()
    oe3 = Shadow.OE()

    # source
    oe0.FDISTR = 3
    oe0.F_COLOR = 2
    oe0.F_PHOT = 0
    oe0.F_POLAR = 0
    oe0.HDIV1 = 0.0
    oe0.HDIV2 = 0.0
    oe0.IDO_VX = 0
    oe0.IDO_VZ = 0
    oe0.IDO_X_S = 0
    oe0.IDO_Y_S = 0
    oe0.IDO_Z_S = 0
    oe0.ISTAR1 = 0
    oe0.NPOINT = 100000
    oe0.N_COLOR = 3
    oe0.PH1 = 799.9
    oe0.PH2 = 800.0
    oe0.PH3 = 800.1
    oe0.SIGDIX = 5e-05
    oe0.SIGDIZ = 0.0
    oe0.SIGMAX = 2e-05
    oe0.SIGMAZ = 0.0
    oe0.VDIV1 = 0.0
    oe0.VDIV2 = 0.0

    # dummy slits tro define source motion
    oe1.DUMMY = 100.0
    oe1.FSTAT = 1
    oe1.F_REFRAC = 2
    oe1.F_SCREEN = 1
    oe1.N_SCREEN = 1
    oe1.RDSOUR = 15.0
    oe1.T_IMAGE = 0.0
    oe1.T_INCIDENCE = 0.0
    oe1.T_REFLECTION = 180.0
    oe1.T_SOURCE = 0.0
    # source motion is here
    oe1.X_SOUR = y_pos_m
    oe1.Y_SOUR = 1e-09
    oe1.Z_SOUR = 1e-09

    # ellipsoidal mirror, cojugate parameters with internally calculated parameters
    oe2.ALPHA = 90.0
    oe2.DUMMY = 100.0
    oe2.FCYL = 1
    oe2.FMIRR = 2
    oe2.FWRITE = 1
    oe2.F_DEFAULT = 0
    #q
    oe2.SIMAG = 5.0
    #p
    oe2.SSOUR = 15.0
    # grazing angle
    oe2.THETA = 88.0
    oe2.T_IMAGE = 0.0
    oe2.T_SOURCE = 0.0

    oe3.DUMMY = 100.0
    oe3.F_REFRAC = 2
    oe3.F_SCREEN = 1
    oe3.N_SCREEN = 1
    oe3.T_IMAGE = 0.0
    oe3.T_INCIDENCE = 0.0
    oe3.T_REFLECTION = 180.0
    oe3.T_SOURCE = 5.0


    beam.genSource(oe0)
    beam.traceOE(oe1,1)
    beam.traceOE(oe2,2)
    beam.traceOE(oe3,3)

    x = beam.getshcol(1)
    y = beam.getshcol(3)

    #x_size_rms_m = numpy.std(x)

    #beam size
    y_size_rms_m = numpy.std(y)

    #Shadow.ShadowTools.plotxy(beam,1,3,nbins=101,nolost=1,title="Real space")
    # Shadow.ShadowTools.plotxy(beam,1,4,nbins=101,nolost=1,title="Phase space X")
    # Shadow.ShadowTools.plotxy(beam,3,6,nbins=101,nolost=1,title="Phase space Z")
    return y_size_rms_m

# %% [markdown]
# ## compute and plot
# (may take a while, typ 20 sec on my computer)

# %%
import matplotlib.pyplot as plt 

source_pos_m = numpy.linspace(-0.010,0.010,101)
y_sizes_m = numpy.zeros(len(source_pos_m))
for i_s in range(len(source_pos_m)):
    y_size_rms_m = shadow_field_size(source_pos_m[i_s])
    y_sizes_m[i_s] = y_size_rms_m

# %%
plt.plot(source_pos_m*1e3,y_sizes_m*1e6)
plt.xlabel("Source position (mm)")
plt.ylabel("Beam size (um)")
plt.title("Beam size at image plane as a function of source position")
plt.grid()
plt.show()
